# %%
import os
import shutil

# %%
# folder names
t2_tse_cor_dcm = "t2_tse_cor_dcm"
True_c = "True_c"
False_c = "False_c"

t2_tse_tra_dcm = "t2_tse_tra_dcm"
True_t = "True_t"
False_t = "False_t"

t2_tse_sag_dcm = "t2_tse_sag_dcm"
True_s = "True_s"
False_s = "False_s"

# %%
#folder creation
os.makedirs(t2_tse_cor_dcm)
os.makedirs(True_c)
os.makedirs(False_c)

for cor_dcm in [True_c, False_c]:
    if os.path.exists(cor_dcm):
        move_folder = os.path.join(t2_tse_cor_dcm, cor_dcm)
        shutil.move(cor_dcm, move_folder)
        print("Complated")
    else:
        print("Failed")
# Out:
# Complated
# Complated

# %%
os.makedirs(t2_tse_tra_dcm)
os.makedirs(True_t)
os.makedirs(False_t)

for tra_dcm in [True_t, False_t]:
    if os.path.exists(tra_dcm):
        move_folder = os.path.join(t2_tse_tra_dcm, tra_dcm)
        shutil.move(tra_dcm, move_folder)
        print("Complated")
    else:
        print("Failed")
# Out:
# Complated
# Complated

# %%
os.makedirs(t2_tse_sag_dcm)
os.makedirs(True_s)
os.makedirs(False_s)

for sag_dcm in [True_s, False_s]:
    if os.path.exists(sag_dcm):
        move_folder = os.path.join(t2_tse_sag_dcm, sag_dcm)
        shutil.move(sag_dcm, move_folder)
        print("Complated")
    else:
        print("Failed")
# Out:
# Complated
# Complated

# %%
#Prostatex Dictionary from csv files
dict_={"ProstateX-0000": "TRUE", "ProstateX-0001": "FALSE", "ProstateX-0003": "FALSE", "ProstateX-0004": "FALSE", "ProstateX-0006": "FALSE", "ProstateX-0007": "FALSE", "ProstateX-0008": "FALSE", "ProstateX-0009": "FALSE", "ProstateX-0010": "FALSE", "ProstateX-0011": "FALSE", "ProstateX-0012": "FALSE", "ProstateX-0013": "FALSE", "ProstateX-0014": "TRUE", "ProstateX-0015": "TRUE", "ProstateX-0016": "FALSE", "ProstateX-0017": "FALSE", "ProstateX-0018": "TRUE", "ProstateX-0019": "TRUE", "ProstateX-0020": "FALSE", "ProstateX-0021": "FALSE", "ProstateX-0022": "FALSE", "ProstateX-0023": "FALSE", "ProstateX-0024": "FALSE", "ProstateX-0025": "FALSE", "ProstateX-0026": "TRUE", "ProstateX-0027": "FALSE", "ProstateX-0029": "FALSE", "ProstateX-0030": "FALSE", "ProstateX-0032": "FALSE", "ProstateX-0033": "FALSE", "ProstateX-0036": "FALSE", "ProstateX-0038": "FALSE", "ProstateX-0039": "FALSE", "ProstateX-0041": "TRUE", "ProstateX-0042": "FALSE", "ProstateX-0043": "FALSE", "ProstateX-0044": "FALSE", "ProstateX-0045": "FALSE", "ProstateX-0047": "FALSE", "ProstateX-0048": "FALSE", "ProstateX-0049": "FALSE", "ProstateX-0050": "FALSE", "ProstateX-0051": "FALSE", "ProstateX-0052": "FALSE", "ProstateX-0053": "FALSE", "ProstateX-0054": "TRUE", "ProstateX-0055": "TRUE", "ProstateX-0056": "FALSE", "ProstateX-0057": "FALSE","ProstateX-0058": "FALSE", "ProstateX-0059":"FALSE", "ProstateX-0060": "FALSE", "ProstateX-0061": "FALSE", "ProstateX-0062": "FALSE", "ProstateX-0063": "FALSE", "ProstateX-0064": "FALSE", "ProstateX-0065": "FALSE", "ProstateX-0066": "FALSE", "ProstateX-0068": "FALSE", "ProstateX-0069": "FALSE", "ProstateX-0070": "FALSE", "ProstateX-0071": "TRUE", "ProstateX-0072": "FALSE", "ProstateX-0073": "FALSE", "ProstateX-0074": "FALSE", "ProstateX-0075": "FALSE", "ProstateX-0076": "FALSE", "ProstateX-0077": "TRUE", "ProstateX-0078": "TRUE", "ProstateX-0079": "FALSE", "ProstateX-0080": "FALSE", "ProstateX-0081": "FALSE", "ProstateX-0082": "TRUE", "ProstateX-0083": "FALSE", "ProstateX-0084": "FALSE", "ProstateX-0085": "FALSE", "ProstateX-0086": "FALSE", "ProstateX-0087": "FALSE", "ProstateX-0088": "FALSE", "ProstateX-0089": "FALSE", "ProstateX-0090": "FALSE", "ProstateX-0091": "FALSE", "ProstateX-0092": "TRUE", "ProstateX-0093": "FALSE", "ProstateX-0094": "TRUE", "ProstateX-0096": "FALSE", "ProstateX-0097": "TRUE", "ProstateX-0098": "FALSE", "ProstateX-0100": "FALSE", "ProstateX-0101": "FALSE", "ProstateX-0102": "TRUE", "ProstateX-0107": "FALSE", "ProstateX-0110": "FALSE", "ProstateX-0111": "TRUE", "ProstateX-0112": "FALSE", "ProstateX-0113": "FALSE", "ProstateX-0115": "TRUE", "ProstateX-0116": "FALSE", "ProstateX-0117": "FALSE", "ProstateX-0119": "TRUE", "ProstateX-0120": "FALSE", "ProstateX-0122": "FALSE", "ProstateX-0123": "TRUE", "ProstateX-0124": "FALSE", "ProstateX-0125": "TRUE", "ProstateX-0127": "TRUE", "ProstateX-0129": "TRUE", "ProstateX-0130": "FALSE", "ProstateX-0132": "FALSE", "ProstateX-0133": "FALSE", "ProstateX-0134": "FALSE","ProstateX-0135": "FALSE", "ProstateX-0136": "FALSE", "ProstateX-0137": "FALSE", "ProstateX-0138": "FALSE", "ProstateX-0140": "FALSE", "ProstateX-0141": "FALSE", "ProstateX-0142": "FALSE", "ProstateX-0143": "TRUE", "ProstateX-0144": "FALSE", "ProstateX-0145": "FALSE", "ProstateX-0146": "FALSE", "ProstateX-0147": "FALSE", "ProstateX-0149": "FALSE", "ProstateX-0150": "FALSE", "ProstateX-0151": "FALSE", "ProstateX-0152": "FALSE", "ProstateX-0153": "FALSE", "ProstateX-0154": "FALSE", "ProstateX-0155": "FALSE", "ProstateX-0156": "FALSE", "ProstateX-0157": "FALSE", "ProstateX-0158": "FALSE", "ProstateX-0159": "FALSE", "ProstateX-0160": "FALSE", "ProstateX-0161": "FALSE", "ProstateX-0162": "FALSE", "ProstateX-0163": "FALSE", "ProstateX-0164": "FALSE", "ProstateX-0165": "FALSE", "ProstateX-0166": "FALSE", "ProstateX-0167": "FALSE", "ProstateX-0168": "FALSE", "ProstateX-0169": "TRUE", "ProstateX-0170": "FALSE", "ProstateX-0171": "FALSE", "ProstateX-0172": "FALSE", "ProstateX-0173": "FALSE", "ProstateX-0174": "FALSE", "ProstateX-0175": "FALSE", "ProstateX-0176": "FALSE", "ProstateX-0177": "FALSE", "ProstateX-0178": "FALSE", "ProstateX-0179": "TRUE", "ProstateX-0180": "FALSE", "ProstateX-0181": "TRUE", "ProstateX-0182": "FALSE", "ProstateX-0183": "TRUE", "ProstateX-0185": "FALSE", "ProstateX-0188": "FALSE", "ProstateX-0189": "FALSE", "ProstateX-0191": "FALSE", "ProstateX-0194": "TRUE", "ProstateX-0195": "TRUE", "ProstateX-0196": "TRUE", "ProstateX-0197": "TRUE", "ProstateX-0198": "TRUE", "ProstateX-0199": "TRUE", "ProstateX-0201": "TRUE", "ProstateX-0203": "TRUE" }

# %%
person_list = list(dict_.keys())

# %%
#Selection of relative type of t2 images
PATH_1 = "/content/prostatex/training_cohort/training_images/manifest-hjL8tlLc1556886850502670511/PROSTATEx/"
SUB_PATH = os.listdir(path=PATH_1)
count = 0
c_True = 0
c_False = 0
for person in SUB_PATH:
  if person != "LICENSE" and person in person_list:
    SUB_PATH2 = os.listdir(path=PATH_1+person)[0]
    SUB_PATH3 = os.listdir(path=PATH_1+person+"/"+SUB_PATH2)
    print(f"For {person}")
    print("-"*20)
    for each in SUB_PATH3:
      if "t2tsecor" in each:
        for img in os.listdir(path=PATH_1+person+"/"+SUB_PATH2 + "/" + each):
          label = dict_[person]
          if label == "TRUE":
            shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/t2_tse_cor_dcm/True_c/{str(count)}.dcm")
            print(f"IMAGE: {img} SAVED INTO TRUE")
            count += 1
            c_True += 1
          else:
            shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/t2_tse_cor_dcm/False_c/{str(count)}.dcm")
            print(f"IMAGE: {img} SAVED INTO FALSE")
            count += 1
            c_False += 1
    print("-"*20)

print(f"Total number of True images: {c_True}")
print(f"Total number of False images: {c_False}")
# Out:
# For ProstateX-0004
# --------------------
# IMAGE: 1-21.dcm SAVED INTO FALSE
# IMAGE: 1-07.dcm SAVED INTO FALSE
# IMAGE: 1-09.dcm SAVED INTO FALSE
# IMAGE: 1-03.dcm SAVED INTO FALSE
# IMAGE: 1-19.dcm SAVED INTO FALSE
# IMAGE: 1-11.dcm SAVED INTO FALSE
# IMAGE: 1-01.dcm SAVED INTO FALSE
# IMAGE: 1-15.dcm SAVED INTO FALSE
# IMAGE: 1-02.dcm SAVED INTO FALSE
# IMAGE: 1-10.dcm SAVED INTO FALSE
# IMAGE: 1-04.dcm SAVED INTO FALSE
# IMAGE: 1-20.dcm SAVED INTO FALSE
# IMAGE: 1-17.dcm SAVED INTO FALSE
# IMAGE: 1-06.dcm SAVED INTO FALSE
# IMAGE: 1-18.dcm SAVED INTO FALSE
# IMAGE: 1-12.dcm SAVED INTO FALSE
# IMAGE: 1-08.dcm SAVED INTO FALSE
# IMAGE: 1-05.dcm SAVED INTO FALSE
# IMAGE: 1-14.dcm SAVED INTO FALSE
# IMAGE: 1-16.dcm SAVED INTO FALSE
# IMAGE: 1-13.dcm SAVED INTO FALSE
# --------------------
# For ProstateX-0071
# --------------------
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# IMAGE: 1-11.dcm SAVED INTO TRUE
# ...

# %%
PATH_1 = "/content/prostatex/training_cohort/training_images/manifest-hjL8tlLc1556886850502670511/PROSTATEx/"
SUB_PATH = os.listdir(path=PATH_1)
count = 0
c_True = 0
c_False = 0
for person in SUB_PATH:
  if person != "LICENSE" and person in person_list:
    SUB_PATH2 = os.listdir(path=PATH_1+person)[0]
    SUB_PATH3 = os.listdir(path=PATH_1+person+"/"+SUB_PATH2)
    print(f"For {person}")
    print("-"*20)
    for each in SUB_PATH3:
      if "t2tsetra" in each:
        for img in os.listdir(path=PATH_1+person+"/"+SUB_PATH2 + "/" + each):
          label = dict_[person]
          if label == "TRUE":
            shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/t2_tse_tra_dcm/True_t/{str(count)}.dcm")
            print(f"IMAGE: {img} SAVED INTO TRUE")
            count += 1
            c_True += 1
          else:
            shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/t2_tse_tra_dcm/False_t/{str(count)}.dcm")
            print(f"IMAGE: {img} SAVED INTO FALSE")
            count += 1
            c_False += 1
    print("-"*20)

print(f"Total number of True images: {c_True}")
print(f"Total number of False images: {c_False}")
# Out:
# For ProstateX-0004
# --------------------
# IMAGE: 1-07.dcm SAVED INTO FALSE
# IMAGE: 1-09.dcm SAVED INTO FALSE
# IMAGE: 1-03.dcm SAVED INTO FALSE
# IMAGE: 1-19.dcm SAVED INTO FALSE
# IMAGE: 1-11.dcm SAVED INTO FALSE
# IMAGE: 1-01.dcm SAVED INTO FALSE
# IMAGE: 1-15.dcm SAVED INTO FALSE
# IMAGE: 1-02.dcm SAVED INTO FALSE
# IMAGE: 1-10.dcm SAVED INTO FALSE
# IMAGE: 1-04.dcm SAVED INTO FALSE
# IMAGE: 1-17.dcm SAVED INTO FALSE
# IMAGE: 1-06.dcm SAVED INTO FALSE
# IMAGE: 1-18.dcm SAVED INTO FALSE
# IMAGE: 1-12.dcm SAVED INTO FALSE
# IMAGE: 1-08.dcm SAVED INTO FALSE
# IMAGE: 1-05.dcm SAVED INTO FALSE
# IMAGE: 1-14.dcm SAVED INTO FALSE
# IMAGE: 1-16.dcm SAVED INTO FALSE
# IMAGE: 1-13.dcm SAVED INTO FALSE
# --------------------
# For ProstateX-0071
# --------------------
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# IMAGE: 1-19.dcm SAVED INTO TRUE
# IMAGE: 1-11.dcm SAVED INTO TRUE
# IMAGE: 1-01.dcm SAVED INTO TRUE
# ...

# %%
PATH_1 = "/content/prostatex/training_cohort/training_images/manifest-hjL8tlLc1556886850502670511/PROSTATEx/"
SUB_PATH = os.listdir(path=PATH_1)
count = 0
c_True = 0
c_False = 0
for person in SUB_PATH:
  if person != "LICENSE" and person in person_list:
    SUB_PATH2 = os.listdir(path=PATH_1+person)[0]
    SUB_PATH3 = os.listdir(path=PATH_1+person+"/"+SUB_PATH2)
    print(f"For {person}")
    print("-"*20)
    for each in SUB_PATH3:
      if "t2tsesag" in each:
        for img in os.listdir(path=PATH_1+person+"/"+SUB_PATH2 + "/" + each):
          label = dict_[person]
          if label == "TRUE":
            shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/t2_tse_sag_dcm/True_s/{str(count)}.dcm")
            print(f"IMAGE: {img} SAVED INTO TRUE")
            count += 1
            c_True += 1
          else:
            shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/t2_tse_sag_dcm/False_s/{str(count)}.dcm")
            print(f"IMAGE: {img} SAVED INTO FALSE")
            count += 1
            c_False += 1
    print("-"*20)

print(f"Total number of True images: {c_True}")
print(f"Total number of False images: {c_False}")
# Out:
# For ProstateX-0004
# --------------------
# IMAGE: 1-07.dcm SAVED INTO FALSE
# IMAGE: 1-09.dcm SAVED INTO FALSE
# IMAGE: 1-03.dcm SAVED INTO FALSE
# IMAGE: 1-19.dcm SAVED INTO FALSE
# IMAGE: 1-11.dcm SAVED INTO FALSE
# IMAGE: 1-01.dcm SAVED INTO FALSE
# IMAGE: 1-15.dcm SAVED INTO FALSE
# IMAGE: 1-02.dcm SAVED INTO FALSE
# IMAGE: 1-10.dcm SAVED INTO FALSE
# IMAGE: 1-04.dcm SAVED INTO FALSE
# IMAGE: 1-17.dcm SAVED INTO FALSE
# IMAGE: 1-06.dcm SAVED INTO FALSE
# IMAGE: 1-18.dcm SAVED INTO FALSE
# IMAGE: 1-12.dcm SAVED INTO FALSE
# IMAGE: 1-08.dcm SAVED INTO FALSE
# IMAGE: 1-05.dcm SAVED INTO FALSE
# IMAGE: 1-14.dcm SAVED INTO FALSE
# IMAGE: 1-16.dcm SAVED INTO FALSE
# IMAGE: 1-13.dcm SAVED INTO FALSE
# --------------------
# For ProstateX-0071
# --------------------
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# IMAGE: 1-19.dcm SAVED INTO TRUE
# IMAGE: 1-11.dcm SAVED INTO TRUE
# IMAGE: 1-01.dcm SAVED INTO TRUE
# ...

# %%
test_t2_tse_cor_dcm = "test_t2_tse_cor_dcm"
test_t2_tse_tra_dcm = "test_t2_tse_tra_dcm"
test_t2_tse_sag_dcm = "test_t2_tse_sag_dcm"

os.makedirs(test_t2_tse_cor_dcm)
os.makedirs(test_t2_tse_tra_dcm)
os.makedirs(test_t2_tse_sag_dcm)

# %%
PATH_1 = "/content/prostatex/test_cohort/test_images/manifest-MQ0R2nDM7840353659486226295/PROSTATEx/"
SUB_PATH = os.listdir(path=PATH_1)
count = 0
for person in SUB_PATH:
  if person != "LICENSE":
    SUB_PATH2 = os.listdir(path=PATH_1+person)[0]
    SUB_PATH3 = os.listdir(path=PATH_1+person+"/"+SUB_PATH2)
    print(f"For {person}")
    print("-"*20)
    for each in SUB_PATH3:
      if "t2tsecor" in each:
        print(each)
        for img in os.listdir(path=PATH_1+person+"/"+SUB_PATH2 + "/" + each):
          shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/test_t2_tse_cor_dcm/{str(count)}.dcm")
          print(f"IMAGE: {img} SAVED INTO TRUE")
          count += 1

    print("-"*20)
# Out:
# For ProstateX-0244
# --------------------
# 5.000000-t2tsecor-61519
# IMAGE: 1-21.dcm SAVED INTO TRUE
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# IMAGE: 1-19.dcm SAVED INTO TRUE
# IMAGE: 1-11.dcm SAVED INTO TRUE
# IMAGE: 1-01.dcm SAVED INTO TRUE
# IMAGE: 1-15.dcm SAVED INTO TRUE
# IMAGE: 1-02.dcm SAVED INTO TRUE
# IMAGE: 1-10.dcm SAVED INTO TRUE
# IMAGE: 1-04.dcm SAVED INTO TRUE
# IMAGE: 1-20.dcm SAVED INTO TRUE
# IMAGE: 1-17.dcm SAVED INTO TRUE
# IMAGE: 1-06.dcm SAVED INTO TRUE
# IMAGE: 1-18.dcm SAVED INTO TRUE
# IMAGE: 1-12.dcm SAVED INTO TRUE
# IMAGE: 1-08.dcm SAVED INTO TRUE
# IMAGE: 1-05.dcm SAVED INTO TRUE
# IMAGE: 1-14.dcm SAVED INTO TRUE
# IMAGE: 1-16.dcm SAVED INTO TRUE
# IMAGE: 1-13.dcm SAVED INTO TRUE
# --------------------
# For ProstateX-0252
# --------------------
# 4.000000-t2tsecor-53782
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# ...

# %%
PATH_1 = "/content/prostatex/test_cohort/test_images/manifest-MQ0R2nDM7840353659486226295/PROSTATEx/"
SUB_PATH = os.listdir(path=PATH_1)
count = 0
for person in SUB_PATH:
  if person != "LICENSE":
    SUB_PATH2 = os.listdir(path=PATH_1+person)[0]
    SUB_PATH3 = os.listdir(path=PATH_1+person+"/"+SUB_PATH2)
    print(f"For {person}")
    print("-"*20)
    for each in SUB_PATH3:
      if "t2tsetra" in each:
        print(each)
        for img in os.listdir(path=PATH_1+person+"/"+SUB_PATH2 + "/" + each):
          shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/test_t2_tse_tra_dcm/{str(count)}.dcm")
          print(f"IMAGE: {img} SAVED INTO TRUE")
          count += 1

    print("-"*20)
# Out:
# For ProstateX-0244
# --------------------
# 4.000000-t2tsetra-68929
# IMAGE: 1-21.dcm SAVED INTO TRUE
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# IMAGE: 1-19.dcm SAVED INTO TRUE
# IMAGE: 1-11.dcm SAVED INTO TRUE
# IMAGE: 1-01.dcm SAVED INTO TRUE
# IMAGE: 1-15.dcm SAVED INTO TRUE
# IMAGE: 1-02.dcm SAVED INTO TRUE
# IMAGE: 1-10.dcm SAVED INTO TRUE
# IMAGE: 1-04.dcm SAVED INTO TRUE
# IMAGE: 1-20.dcm SAVED INTO TRUE
# IMAGE: 1-23.dcm SAVED INTO TRUE
# IMAGE: 1-17.dcm SAVED INTO TRUE
# IMAGE: 1-06.dcm SAVED INTO TRUE
# IMAGE: 1-18.dcm SAVED INTO TRUE
# IMAGE: 1-12.dcm SAVED INTO TRUE
# IMAGE: 1-08.dcm SAVED INTO TRUE
# IMAGE: 1-05.dcm SAVED INTO TRUE
# IMAGE: 1-14.dcm SAVED INTO TRUE
# IMAGE: 1-22.dcm SAVED INTO TRUE
# IMAGE: 1-16.dcm SAVED INTO TRUE
# IMAGE: 1-13.dcm SAVED INTO TRUE
# --------------------
# For ProstateX-0252
# --------------------
# 5.000000-t2tsetra-34213
# IMAGE: 1-21.dcm SAVED INTO TRUE
# ...

# %%
PATH_1 = "/content/prostatex/test_cohort/test_images/manifest-MQ0R2nDM7840353659486226295/PROSTATEx/"
SUB_PATH = os.listdir(path=PATH_1)
count = 0
for person in SUB_PATH:
  if person != "LICENSE":
    SUB_PATH2 = os.listdir(path=PATH_1+person)[0]
    SUB_PATH3 = os.listdir(path=PATH_1+person+"/"+SUB_PATH2)
    print(f"For {person}")
    print("-"*20)
    for each in SUB_PATH3:
      if "t2tsesag" in each:
        print(each)
        for img in os.listdir(path=PATH_1+person+"/"+SUB_PATH2 + "/" + each):
          shutil.copy(PATH_1+person+"/"+SUB_PATH2 + "/" + each + "/" + img , f"/content/test_t2_tse_sag_dcm/{str(count)}.dcm")
          print(f"IMAGE: {img} SAVED INTO TRUE")
          count += 1

    print("-"*20)
# Out:
# For ProstateX-0244
# --------------------
# 3.000000-t2tsesag-30325
# IMAGE: 1-21.dcm SAVED INTO TRUE
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# IMAGE: 1-19.dcm SAVED INTO TRUE
# IMAGE: 1-11.dcm SAVED INTO TRUE
# IMAGE: 1-01.dcm SAVED INTO TRUE
# IMAGE: 1-15.dcm SAVED INTO TRUE
# IMAGE: 1-02.dcm SAVED INTO TRUE
# IMAGE: 1-10.dcm SAVED INTO TRUE
# IMAGE: 1-04.dcm SAVED INTO TRUE
# IMAGE: 1-20.dcm SAVED INTO TRUE
# IMAGE: 1-17.dcm SAVED INTO TRUE
# IMAGE: 1-06.dcm SAVED INTO TRUE
# IMAGE: 1-18.dcm SAVED INTO TRUE
# IMAGE: 1-12.dcm SAVED INTO TRUE
# IMAGE: 1-08.dcm SAVED INTO TRUE
# IMAGE: 1-05.dcm SAVED INTO TRUE
# IMAGE: 1-14.dcm SAVED INTO TRUE
# IMAGE: 1-16.dcm SAVED INTO TRUE
# IMAGE: 1-13.dcm SAVED INTO TRUE
# 9.000000-t2tsesag-31214
# IMAGE: 1-21.dcm SAVED INTO TRUE
# IMAGE: 1-07.dcm SAVED INTO TRUE
# IMAGE: 1-09.dcm SAVED INTO TRUE
# IMAGE: 1-03.dcm SAVED INTO TRUE
# IMAGE: 1-19.dcm SAVED INTO TRUE
# ...

# %%
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.6 MB/s eta 0:00:00
# ...

# %%
import pydicom
from PIL import Image
import numpy as np

# %%
# readind dcm files
def reach_dcm_files(dcmpath):
    dcm_files_names = []
    for dcmr, dcmfolders, dcmfiles in os.walk(dcmpath):
        for dcmfile in dcmfiles:
            _, ext = os.path.splitext(dcmfile)
            if ext in ['.dcm']:
                dcm_files_names.append(dcmfile)

    return dcm_files_names

# %%
#dcm to png convert
def dcm_to_png_converting(directory, dcm_files_name):

    dcm_to_png = pydicom.dcmread(directory + dcm_files_name)

    dcm_to_png = dcm_to_png.pixel_array.astype(float)

    dcm_to_png_rescale = (np.maximum(dcm_to_png,0)/dcm_to_png.max())*255 # float pixels
    png_image = np.uint8(dcm_to_png_rescale) # integers pixels

    png_image = Image.fromarray(png_image)

    return png_image

# %%
# delete dcm files
def delete_old_files(directory):
	reach_dir = os.listdir(directory)
	old_files = [oldfile for oldfile in reach_dir if oldfile.endswith(".dcm")]
	for oldfile in old_files:
		path_to_file = os.path.join(directory, oldfile)
		os.remove(path_to_file)

# %%
dcm_files_names = reach_dcm_files('/content/t2_tse_cor_dcm/False_c/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/t2_tse_cor_dcm/False_c/', dcm_files_name)
    os.chdir('/content/t2_tse_cor_dcm/False_c')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/t2_tse_cor_dcm/False_c'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/t2_tse_cor_dcm/True_c/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/t2_tse_cor_dcm/True_c/', dcm_files_name)
    os.chdir('/content/t2_tse_cor_dcm/True_c')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/t2_tse_cor_dcm/True_c'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/t2_tse_sag_dcm/False_s/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/t2_tse_sag_dcm/False_s/', dcm_files_name)
    os.chdir('/content/t2_tse_sag_dcm/False_s')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/t2_tse_sag_dcm/False_s'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/t2_tse_sag_dcm/True_s/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/t2_tse_sag_dcm/True_s/', dcm_files_name)
    os.chdir('/content/t2_tse_sag_dcm/True_s')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/t2_tse_sag_dcm/True_s'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/t2_tse_tra_dcm/False_t/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/t2_tse_tra_dcm/False_t/', dcm_files_name)
    os.chdir('/content/t2_tse_tra_dcm/False_t')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/t2_tse_tra_dcm/False_t'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/t2_tse_tra_dcm/True_t/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/t2_tse_tra_dcm/True_t/', dcm_files_name)
    os.chdir('/content/t2_tse_tra_dcm/True_t')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/t2_tse_tra_dcm/True_t'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/test_t2_tse_cor_dcm/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/test_t2_tse_cor_dcm/', dcm_files_name)
    os.chdir('/content/test_t2_tse_cor_dcm')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/test_t2_tse_cor_dcm'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/test_t2_tse_sag_dcm/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/test_t2_tse_sag_dcm/', dcm_files_name)
    os.chdir('/content/test_t2_tse_sag_dcm')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/test_t2_tse_sag_dcm'

delete_old_files(directory)

# %%
dcm_files_names = reach_dcm_files('/content/test_t2_tse_tra_dcm/')
for dcm_files_name in dcm_files_names:
    png_image = dcm_to_png_converting('/content/test_t2_tse_tra_dcm/', dcm_files_name)
    os.chdir('/content/test_t2_tse_tra_dcm')
    png_image.save(dcm_files_name+'.png')

# %%
directory = '/content/test_t2_tse_tra_dcm'

delete_old_files(directory)
